# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
#Imports
from fastai import *
from fastai.vision import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy as sp
from functools import partial
from sklearn import metrics
from collections import Counter
from fastai.callbacks import *
import PIL
import cv2
import sklearn
import skimage
bs = 64

# %%
#images_path
path_images = Path('bc-data')

# %%
#data path and init


data = ImageDataBunch.from_folder(path=path_images, train='train', valid='valid', bs=bs, classes=['0','1','2']) 
data.normalize()
# Out:
# ImageDataBunch;
#
# Train: LabelList (13498 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 1,1,1,1,1
# Path: bc-data;
#
# Valid: LabelList (2700 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 0,0,0,0,0
# Path: bc-data;
#
# Test: None

# %%
data.classes
# Out:
# ['0', '1', '2']

# %%
learn = cnn_learner(data, models.densenet201, metrics=error_rate)
learn.freeze()
# Out:
# Downloading: "https://download.pytorch.org/models/densenet201-c1103571.pth" to /root/.cache/torch/checkpoints/densenet201-c1103571.pth
# 100%|██████████| 77.4M/77.4M [00:01<00:00, 52.9MB/s]

# %%
# learn.freeze()
learn.lr_find(start_lr=1e-5, end_lr=1e1, wd=5e-3)
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.38E-04
# Min loss divided by 10: 9.12E-03

# %%
learn.fit_one_cycle(1, max_lr=slice(1.2e-4, 5e-3))
#learn.save('-stage1')
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.361994</td>
#       <td>0.358166</td>
#       <td>0.131111</td>
#       <td>01:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(8, max_lr=slice(1.2e-4, 5e-3), wd=1e-4)
learn.save('cells-d201-usampled')
learn.recorder.plot_losses()
# # schedule of the lr (left) and momentum (right) that the 1cycle policy uses
learn.recorder.plot_lr(show_moms=True)
learn.recorder.plot_metrics()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.256525</td>
#       <td>0.407155</td>
#       <td>0.140000</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.269847</td>
#       <td>0.423188</td>
#       <td>0.131852</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.243928</td>
#       <td>0.446387</td>
#       <td>0.138519</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.161709</td>
#       <td>0.427653</td>
#       <td>0.120370</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.103846</td>
#       <td>0.473305</td>
#       <td>0.116296</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.065656</td>
#       <td>0.505116</td>
#       <td>0.121111</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.040521</td>
#       <td>0.520083</td>
#       <td>0.118148</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.027199</td>
#       <td>0.519935</td>
#       <td>0.117407</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('cells-d201-usampled')
learn.export('cells-d201-usampled.pkl')

# %%
learn.load('cells-d201-usampled')
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(8,8))

# %%
interp.plot_confusion_matrix(normalize=True, figsize=(8,8))

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
# path_images = Path('cnrs')
data = ImageDataBunch.from_folder(path=path_images, train='train', valid='test', bs=bs, classes=['0','1','2']) 
data.normalize()
# Out:
# ImageDataBunch;
#
# Train: LabelList (13498 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 1,1,1,1,1
# Path: bc-data;
#
# Valid: LabelList (2419 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 1,1,1,1,1
# Path: bc-data;
#
# Test: None

# %%
learn = cnn_learner(data, models.densenet201, metrics=error_rate)

# %%
learn = learn.load('cells-d201-usampled')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(normalize=True, figsize=(8,8))

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
import glob

image_list = glob.glob('bc-data/test/*/*')

C0 = 0
Pred_C0=0
C1=0
Pred_C1=0
C2=0
Pred_C2=0

for each in image_list:
    img = open_image(each)
    each = each.split('/')
    bc_class = each[2]
    pred_class, pred_idx, outputs = learn.predict(img)
    pred_class = str(pred_class)
         
    if bc_class == '0':
        C0 += 1
        if pred_class == '0':
            Pred_C0 += 1
    elif bc_class == '1':
        C1 += 1
        if pred_class == '1':
            Pred_C1 += 1
    elif bc_class == '2':
        C2 += 1
        if pred_class == '2':
            Pred_C2 += 1
            
    
print('C0 classification: ' + str(Pred_C0) + '/' + str(C0))
print('C1 classification: ' + str(Pred_C1) + '/' + str(C1))
print('C2 classification: ' + str(Pred_C2) + '/' + str(C2) )
# Out:
# C0 classification: 636/750
# C1 classification: 560/669
# C2 classification: 838/1000

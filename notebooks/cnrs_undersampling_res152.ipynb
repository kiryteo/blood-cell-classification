# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %cd drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
#Imports
from fastai import *
from fastai.vision import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy as sp
from functools import partial
from sklearn import metrics
from collections import Counter
from fastai.callbacks import *
import PIL
import cv2
import sklearn
import skimage
bs = 64

# %%
#images_path
path_images = Path('bc-data')

# %%
#data path and init


data = ImageDataBunch.from_folder(path=path_images, train='train', valid='valid', bs=bs, classes=['0','1','2']) 
data.normalize()
# Out:
# ImageDataBunch;
#
# Train: LabelList (13498 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 1,1,1,1,1
# Path: bc-data;
#
# Valid: LabelList (2700 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 0,0,0,0,0
# Path: bc-data;
#
# Test: None

# %%
data.classes
# Out:
# ['0', '1', '2']

# %%
learn = cnn_learner(data, models.resnet152, metrics=error_rate)
learn.freeze()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/checkpoints/resnet152-b121ed2d.pth
# 100%|██████████| 230M/230M [00:02<00:00, 105MB/s]

# %%
# learn.freeze()
learn.lr_find(start_lr=1e-5, end_lr=1e1, wd=5e-3)
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.16E-04
# Min loss divided by 10: 6.92E-03

# %%
learn.fit_one_cycle(1, max_lr=slice(4e-4, 2e-3))
#learn.save('-stage1')
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.434519</td>
#       <td>0.410915</td>
#       <td>0.141481</td>
#       <td>33:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(6, max_lr=slice(4e-4, 2e-3), wd=1e-4)
learn.save('cells-res152-usampled')
learn.recorder.plot_losses()
# # schedule of the lr (left) and momentum (right) that the 1cycle policy uses
learn.recorder.plot_lr(show_moms=True)
learn.recorder.plot_metrics()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.316635</td>
#       <td>0.472873</td>
#       <td>0.159630</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.307283</td>
#       <td>0.380106</td>
#       <td>0.128148</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.239893</td>
#       <td>0.372108</td>
#       <td>0.132963</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.166539</td>
#       <td>0.397162</td>
#       <td>0.132222</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.098852</td>
#       <td>0.415700</td>
#       <td>0.116296</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.073790</td>
#       <td>0.423470</td>
#       <td>0.114815</td>
#       <td>01:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('cells-res152-usampled')
learn.export('cells-res152-usampled.pkl')

# %%
learn.load('cells-res152-usampled')
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(8,8))

# %%
interp.plot_confusion_matrix(normalize=True, figsize=(8,8))

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
# path_images = Path('cnrs')
data = ImageDataBunch.from_folder(path=path_images, train='train', valid='test', bs=bs, classes=['0','1','2']) 
data.normalize()
# Out:
# ImageDataBunch;
#
# Train: LabelList (13498 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 1,1,1,1,1
# Path: bc-data;
#
# Valid: LabelList (2419 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# 1,1,1,1,1
# Path: bc-data;
#
# Test: None

# %%
learn = cnn_learner(data, models.resnet152, metrics=error_rate)

# %%
learn = learn.load('cells-res152-usampled')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(normalize=True, figsize=(8,8))

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
import glob

image_list = glob.glob('bc-data/test/*/*')

C0 = 0
Pred_C0=0
C1=0
Pred_C1=0
C2=0
Pred_C2=0

for each in image_list:
    img = open_image(each)
    each = each.split('/')
    bc_class = each[2]
    pred_class, pred_idx, outputs = learn.predict(img)
    pred_class = str(pred_class)
         
    if bc_class == '0':
        C0 += 1
        if pred_class == '0':
            Pred_C0 += 1
    elif bc_class == '1':
        C1 += 1
        if pred_class == '1':
            Pred_C1 += 1
    elif bc_class == '2':
        C2 += 1
        if pred_class == '2':
            Pred_C2 += 1
            
    
print('C0 classification: ' + str(Pred_C0) + '/' + str(C0))
print('C1 classification: ' + str(Pred_C1) + '/' + str(C1))
print('C2 classification: ' + str(Pred_C2) + '/' + str(C2) )
# Out:
# C0 classification: 684/750
# C1 classification: 493/669
# C2 classification: 860/1000

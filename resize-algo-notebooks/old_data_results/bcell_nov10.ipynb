# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd drive/My\ Drive/

# %%
# %cd 10nov

# %%
# !unzip 'train.zip'

# %%
# !unzip 'valid.zip'

# %%
# !unzip 'test.zip'

# %%
#Imports
from fastai import *
from fastai.vision import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy as sp
from functools import partial
from sklearn import metrics
from collections import Counter
from fastai.callbacks import *
import PIL
import cv2
import sklearn
import skimage
bs = 64

# %%
# %cd ..

# %%
#images_path
path_images = Path('10nov')

# %%
#data path and init


data = ImageDataBunch.from_folder(path=path_images, train='train', valid='valid', bs=bs, classes=['TT','others','garbage']) 
data.normalize()
# Out:
# ImageDataBunch;
#
# Train: LabelList (26600 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# garbage,garbage,garbage,garbage,garbage
# Path: 10nov;
#
# Valid: LabelList (7800 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# garbage,garbage,garbage,garbage,garbage
# Path: 10nov;
#
# Test: None

# %%
data.classes
# Out:
# ['TT', 'others', 'garbage']

# %%
learn = create_cnn(data, models.densenet161, metrics=error_rate)
learn.freeze()
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
# learn.freeze()
learn.lr_find(start_lr=1e-6, end_lr=1e1, wd=5e-3)
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 4.57E-04
# Min loss divided by 10: 1.78E-02

# %%
learn.fit_one_cycle(1, max_lr=slice(4.5e-4, 2e-2))
#learn.save('-stage1')
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.281976</td>
#       <td>0.235657</td>
#       <td>0.090385</td>
#       <td>04:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5, max_lr=slice(4.5e-4, 2e-2))
learn.save('bcells-nov10')
learn.recorder.plot_losses()
# # schedule of the lr (left) and momentum (right) that the 1cycle policy uses
learn.recorder.plot_lr(show_moms=True)
learn.recorder.plot_metrics()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.331388</td>
#       <td>0.348504</td>
#       <td>0.091923</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.280675</td>
#       <td>0.235754</td>
#       <td>0.083974</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.234961</td>
#       <td>0.220684</td>
#       <td>0.079615</td>
#       <td>03:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.201895</td>
#       <td>0.206015</td>
#       <td>0.073333</td>
#       <td>03:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.140337</td>
#       <td>0.191645</td>
#       <td>0.071282</td>
#       <td>03:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('bcells-nov10')
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(8,8))

# %%
interp.plot_confusion_matrix(normalize=True, figsize=(8,8))

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
# path_images = Path('cnrs')
data = ImageDataBunch.from_folder(path=path_images, train='train', valid='test', bs=bs, classes=['TT','others','garbage']) 
data.normalize()
# Out:
# ImageDataBunch;
#
# Train: LabelList (26600 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# garbage,garbage,garbage,garbage,garbage
# Path: 10nov;
#
# Valid: LabelList (8096 items)
# x: ImageList
# Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248),Image (3, 31, 248)
# y: CategoryList
# garbage,garbage,garbage,garbage,garbage
# Path: 10nov;
#
# Test: None

# %%
learn = cnn_learner(data, models.densenet161, metrics=error_rate)

# %%
learn = learn.load('bcells-nov10')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(normalize=True, figsize=(8,8))

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
import glob

image_list = glob.glob('10nov/test/*/*')

C0 = 0
Pred_C0=0
C1=0
Pred_C1=0
C2=0
Pred_C2=0

for each in image_list:
    img = open_image(each)
    each = each.split('/')
    bc_class = each[2]
    pred_class, pred_idx, outputs = learn.predict(img)
    pred_class = str(pred_class)
         
    if bc_class == 'TT':
        C0 += 1
        if pred_class == 'TT':
            Pred_C0 += 1
    elif bc_class == 'others':
        C1 += 1
        if pred_class == 'others':
            Pred_C1 += 1
    elif bc_class == 'garbage':
        C2 += 1
        if pred_class == 'garbage':
            Pred_C2 += 1
            
    
print('TT classification: ' + str(Pred_C0) + '/' + str(C0))
print('others classification: ' + str(Pred_C1) + '/' + str(C1))
print('garbage classification: ' + str(Pred_C2) + '/' + str(C2) )
# Out:
# TT classification: 2229/2372
# others classification: 523/724
# garbage classification: 4675/5000
